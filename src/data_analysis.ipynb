# %%
import pandas as pd

# %%
df = pd.read_csv("vuelos.csv", names = ["Vuelo_ida", "Fecha_ida", "Vuelo_vuelta", "Fecha_vuelta", "Fecha_consulta", "Precio_consulta", "Vendedor"])
df.head()
# Out:
#                             Vuelo_ida           Fecha_ida  \
# 0  KL1688| Operado por KLM Cityhopper  lun., 14 nov. 2022
# 1  KL1688| Operado por KLM Cityhopper  lun., 14 nov. 2022
# 2  KL1688| Operado por KLM Cityhopper  lun., 14 nov. 2022
# 3  KL1688| Operado por KLM Cityhopper  lun., 14 nov. 2022
# 4  KL1688| Operado por KLM Cityhopper  lun., 14 nov. 2022
#
#                          Vuelo_vuelta       Fecha_vuelta  \
# 0  KL1687| Operado por KLM Cityhopper  sáb., 3 dic. 2022
# 1  KL1687| Operado por KLM Cityhopper  sáb., 3 dic. 2022
# 2  KL1687| Operado por KLM Cityhopper  sáb., 3 dic. 2022
# 3  KL1687| Operado por KLM Cityhopper  sáb., 3 dic. 2022
# 4  KL1687| Operado por KLM Cityhopper  sáb., 3 dic. 2022
#
#                Fecha_consulta Precio_consulta  Vendedor
# 0  2022-10-30 22:08:10.971586           179 €  eDreams
# 1  2022-10-30 22:09:39.792694           179 €  eDreams
# 2  2022-10-30 22:10:13.306101           179 €  eDreams
# 3  2022-10-30 22:11:16.917216           177 €  eDreams
# 4  2022-10-30 22:12:28.239575           177 €  eDreams

# %%
df.Vuelo_ida.unique()
# Out:
# array(['KL1688| Operado por KLM Cityhopper', 'AF1377| Operado por HOP!',
#        'IB5602| Operado por Vueling Airlines', 'VY8354', 'VY1466',
#        'SN3714', 'VY3974', nan], dtype=object)

# %%
#df_ = df[df.Vuelo_ida == "KL1688| Operado por KLM Cityhopper"]
#df_ = df[df['Vuelo_ida'].str.startswith("KL")] # No funciona si hay nan
df_ = df[df['Vuelo_ida'].str.contains('VY1466', na=False)]

# %%
df_.tail()
# Out:
#     Vuelo_ida          Fecha_ida Vuelo_vuelta       Fecha_vuelta  \
# 89     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 92     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 95     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 98     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 101    VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
#
#                  Fecha_consulta Precio_consulta                      Vendedor
# 89   2022-11-27 13:23:00.682746            88 €                      eDreams
# 92   2022-11-27 17:43:59.234230            94 €  Vueling Airlines \nAerolínea
# 95   2022-11-27 20:00:30.902357            89 €                     Trip.com
# 98   2022-11-28 11:30:04.913597            94 €                     Trip.com
# 101  2022-11-29 13:18:18.488805            93 €                      eDreams

# %%
# Eliminar el '€' y convertir el dato a int
df_["Precio_consulta"] = df_['Precio_consulta'].str.rstrip('€')
df__ = df_.astype({'Precio_consulta':'int'})
# Out:
# C:\Users\akoun\AppData\Local\Temp\ipykernel_2856\563886801.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_["Precio_consulta"] = df_['Precio_consulta'].str.rstrip('€')

# %%
df__
# Out:
#     Vuelo_ida          Fecha_ida Vuelo_vuelta       Fecha_vuelta  \
# 40     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 41     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 49     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 51     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 53     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 56     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 59     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 62     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 65     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 68     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 71     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 74     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 77     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 80     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 83     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 86     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 89     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 92     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 95     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 98     VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
# 101    VY1466  vie., 3 feb. 2023       VY1467  dom., 5 feb. 2023
#
#                  Fecha_consulta  Precio_consulta                      Vendedor
# 40   2022-11-14 20:12:13.211769               93                     Trip.com
# 41   2022-11-14 20:24:10.372975               93                     Trip.com
# 49   2022-11-16 18:21:44.593442               91                     Trip.com
# 51   2022-11-16 18:23:19.889676               91                     Trip.com
# 53   2022-11-20 11:34:42.447214               94                     Trip.com
# 56   2022-11-21 16:30:11.382789               94                     Trip.com
# 59   2022-11-21 16:42:26.444497               93                  Booking.com
# 62   2022-11-21 16:46:20.673194               93                      eDreams
# 65   2022-11-21 17:04:39.774631               93                     Trip.com
# 68   2022-11-22 17:11:13.557129               94                     Trip.com
# 71   2022-11-22 18:10:18.513652               88                      eDreams
# 74   2022-11-22 19:19:12.646715               88                      eDreams
# 77   2022-11-22 19:30:17.731497               88                      eDreams
# 80   2022-11-24 16:39:05.899932              102                     Trip.com
# 83   2022-11-25 11:43:47.405865               96                        Opodo
# 86   2022-11-26 21:21:55.873502               93                     Trip.com
# 89   2022-11-27 13:23:00.682746               88                      eDreams
# 92   2022-11-27 17:43:59.234230               94  Vueling Airlines \nAerolínea
# 95   2022-11-27 20:00:30.902357               89                     Trip.com
# 98   2022-11-28 11:30:04.913597               94                     Trip.com
# 101  2022-11-29 13:18:18.488805               93                      eDreams

# %%
import matplotlib.pyplot as plt
#https://www.analyticslane.com/2018/07/06/agrupacion-de-datos-por-fecha-en-pandas/

df__.plot(x="Fecha_consulta", y="Precio_consulta")
# Out:
# <AxesSubplot: xlabel='Fecha_consulta'>
